# %%
# %cd models/yolov7
# Out:
# c:\Users\hoang\OneDrive\Desktop\edabk\Violent_detection_from_drone\models\yolov7

# %%
from extract_frame import *

detect({
        "weight": "../../weights/yolov7/best.pt",
        "img-size": 100,
        "source": "../../videos",
        "device": "cpu",
        "classes": None,
        "conf_thres": 0.8,  # confidence threshold for inference.
        "iou_thres": 0.65  # NMS IoU threshold for inference.
    })
# Out:
# Fusing layers...
# IDetect.fuse
# WARNING: --img-size 100 must be multiple of max stride 32, updating to 128
# video 1/2 (1/345) c:\Users\hoang\OneDrive\Desktop\edabk\Violent_detection_from_drone\models\yolov7\..\..\videos\Violence_9_drone - 4of12.mp4: OK
# video 1/2 (2/345) c:\Users\hoang\OneDrive\Desktop\edabk\Violent_detection_from_drone\models\yolov7\..\..\videos\Violence_9_drone - 4of12.mp4: SAME
# video 1/2 (3/345) c:\Users\hoang\OneDrive\Desktop\edabk\Violent_detection_from_drone\models\yolov7\..\..\videos\Violence_9_drone - 4of12.mp4: SAME
# video 1/2 (4/345) c:\Users\hoang\OneDrive\Desktop\edabk\Violent_detection_from_drone\models\yolov7\..\..\videos\Violence_9_drone - 4of12.mp4: SAME
# video 1/2 (5/345) c:\Users\hoang\OneDrive\Desktop\edabk\Violent_detection_from_drone\models\yolov7\..\..\videos\Violence_9_drone - 4of12.mp4: SAME
# ...
